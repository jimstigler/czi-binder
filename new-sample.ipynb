# %%
model_sex <- lm(Thumb ~ Sex, data = Fingers)
anova_sex <- supernova(model_sex)
print(anova_sex, pcut = 6)
# Out:
#  Analysis of Variance Table (Type III SS)
#  Model: Thumb ~ Sex
#
#                                 SS  df       MS      F    PRE       p
#  ----- ----------------- --------- --- -------- ------ ------ -------
#  Model (error reduced) |  1334.203   1 1334.203 19.609 0.1123 .000018
#  Error (from model)    | 10546.008 155   68.039
#  ----- ----------------- --------- --- -------- ------ ------ -------
#  Total (empty model)   | 11880.211 156   76.155

# %%
gf_histogram(~Thumb, data=Fingers)
# Out:
# plot without title

# %%
# write your own code here
